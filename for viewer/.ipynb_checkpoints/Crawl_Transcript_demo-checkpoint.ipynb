# %% [markdown]
# # 爬蟲

# %%
import numpy as np
import pandas as pd
import text_cleaning
import visualization
from YT_Transcript_Crawl import transcript_crawl

# %%
keyword = "台中旅遊"
YOUTUBE_API_KEY = "AIzaSyDTknTFDZbn-AhdCDZ7leKU7EGs9EHL8vA"
df = transcript_crawl(keyword,YOUTUBE_API_KEY)
# Out:
# 23 0.08679245283018867

# %%
df
# Out:
#               id                   channelTitle         publishedAt  \
# 0    -7Ka2Tdb3O4                   大玩台中-臺中觀光旅遊局 2020-07-03 02:30:12
# 1    vPqaguNOCBs                         見習網美小吳 2019-09-11 13:00:27
# 2    yRSvmHcoi7I               Spice Travel 辣旅遊 2019-10-25 15:32:02
# 3    GGHnpnSk1GU                    WennnTV溫蒂頻道 2018-05-11 13:00:01
# 4    CsC8TFbsHvw               TommyTommy Japan 2020-02-05 11:00:04
# ..           ...                            ...                 ...
# 260  W0FSMakHUhg                   LadyHaha哈哈姐妹 2020-09-20 11:51:22
# 261  Q7l_R7Z1Xl4                           Nini 2018-04-04 17:58:23
# 262  RJ-HKzqfhW4  Scrolling Channel 逛逛頻道 台中逛逛!! 2019-11-12 14:47:13
# 263  QQDPAi15lZw                      FOOD 幸福食光 2020-01-14 09:19:31
# 264  4ds8VrqCvrY                      飛安之殿堂Fion 2021-05-19 12:00:00
#
#                                        video_url  \
# 0    https://www.youtube.com/watch?v=-7Ka2Tdb3O4
# 1    https://www.youtube.com/watch?v=vPqaguNOCBs
# 2    https://www.youtube.com/watch?v=yRSvmHcoi7I
# 3    https://www.youtube.com/watch?v=GGHnpnSk1GU
# 4    https://www.youtube.com/watch?v=CsC8TFbsHvw
# ..                                           ...
# 260  https://www.youtube.com/watch?v=W0FSMakHUhg
# 261  https://www.youtube.com/watch?v=Q7l_R7Z1Xl4
# 262  https://www.youtube.com/watch?v=RJ-HKzqfhW4
# 263  https://www.youtube.com/watch?v=QQDPAi15lZw
# 264  https://www.youtube.com/watch?v=4ds8VrqCvrY
#
#                                                  title  \
# 0            Taichung. The Heart of Taiwan. 臺中城市觀光行銷影片
# 1    【小吳 】台中微網美一日遊～幕後人員全員公開！跟著我們逛～(ft.ASUS ZenBook ...
# 2     Spice 秘境🌶 | 台中人都不知道這些地方?! 一日隱藏版台中輕旅行 | 台中 自由行 景點
# 3           【台中秘境Ep.1】超美！帶你去夏天旅行絕不能錯過的台中秘境！WennnTV溫蒂頻道
# 4    第一次帶日本朋友到台灣台中旅行! 夜市美食讓人一吃就愛上, 網美景點太漂亮!!【Tommy ...
# ..                                                 ...
# 260  【台中旅遊Vlog】馬拉灣【Taichung VLOG】Taiwan travel tour...
# 261                               旅遊｜台中旅遊新景點-大雅台灣童玩故事館
# 262  台中旅遊 | 【2019新社花海】  | 台中景點 | 最新花海創意攝影剪輯 | 新社花海繽...
# 263                       【蔬食旅遊 第一品牌】《台中南區》美味搶先看2－花見松露
# 264  外國人去台中旅遊必定會去的清境青青草原丨入場只需要二百塊就可以玩小綿羊啦丨Insta360 ...
#
#                                            description likeCount commentCount  \
# 0    「臺中29區絕景」專書  https://travel.taichung.gov.tw/zh...      1431          142
# 1    台中的粉絲豪～熱～情～啊～\n我們來找一直陪著我們的片師傑克啦\n包車直衝台中，挑戰一日微網...     13156          373
# 2    Spice這次來到大家敲碗很久的台中啦~ 台中真的是個充滿文化藝術、傳統與現代結合的地方耶！...      6964          201
# 3    ➙訂閱我的頻道 看我最新影片▶️https://pse.is/JKBTU\n（點開下面還有得...      2704          141
# 4    下集的高雄vlog https://youtu.be/i4maF8Fb3Y4\n\nTomm...     14947         1026
# ..                                                 ...       ...          ...
# 260  高聳刺激的滑水道\n沁涼身心的大海嘯\n快點跟著我們抓緊夏天的尾巴吧～\n\n🔖台中麗寶樂園...        10            4
# 261                     感謝台灣童玩故事館邀請\n讓我們團隊能夠邊拍攝邊回味一下童年         0            1
# 262  #2019新社花海 #新社花海 #台中景點\n\nʕ•ᴥ•ʔ 讓本節目來📹介紹你的餐廳🍽\n...         7            0
# 263  完整版線上看 https://youtu.be/vh7fJiOiuqo\n歡迎訂閱 幸福食光...         8            2
# 264  2017年中學畢業的我 馬上去玩啦～～～那時候搜尋台中去哪裡玩,都會說清境，所以外國人去台中...        24            0
#
#     viewCount transcript
# 0     1050191
# 1      865663
# 2      670270
# 3      471942
# 4      448121
# ..        ...        ...
# 260       298
# 261       294
# 262       293
# 263       292
# 264       285
#
# [265 rows x 10 columns]

# %%
df.loc[0,'transcript']
# Out:
# ''

# %% [markdown]
# # 分析

# %%
transcript_data = df[df['transcript']!=''].reset_index(drop=True)
transcript_data
# Out:
#              id                      channelTitle         publishedAt  \
# 0   3fBj-p5GqzQ                            dd邊走邊吃 2022-02-20 14:00:06
# 1   mxfcE15RN_A                               丁小羽 2019-10-31 12:00:09
# 2   hwwD7mAMo-A                              默森夫妻 2017-03-19 13:00:04
# 3   dfMAQsBbdHo                             我都ok啊 2020-10-26 13:00:08
# 4   zIOAXiedPNY                             蔡劭與尼莫 2016-12-23 14:36:21
# 5   2ADLyEO0vMA                          環遊世界的小羊兒 2019-03-15 15:40:36
# 6   _xBTrGoFWRA            七星哥旅遊 StarsEvalSuggest 2020-09-19 16:11:38
# 7   iVH5ozXvcmQ                             蔡劭與尼莫 2019-01-11 19:09:45
# 8   i1ChquJ0KKY                  蓓貝兒 Beibeier 愛旅遊 2020-11-28 14:00:13
# 9   RbijOO1rNt8                             蔡劭與尼莫 2019-01-20 10:58:56
# 10  yyR3CKMqL9A                             蔡劭與尼莫 2018-12-11 22:58:22
# 11  6BPWvwsWvJQ                             蔡劭與尼莫 2020-09-03 02:19:52
# 12  SBykI063Zt0                             蔡劭與尼莫 2018-12-30 23:00:05
# 13  i55K3Ta7YvU                             蔡劭與尼莫 2017-02-16 22:37:05
# 14  hwRuUyRVic0  民視綜藝娛樂 Formosa TV Entertainments 2021-11-15 04:15:00
# 15  JZxXWaKYLsk                                拾承 2021-11-25 11:00:07
# 16  C7g3sfmU3Fg             驢子等人Donkey & Somebody 2021-08-08 14:00:04
# 17  UB_8fV0Z-A0                  旅行優先TRAVEL FIRST 2021-03-04 06:35:15
# 18  I5Wje92vjig                              遊玩食光 2020-10-28 08:53:42
# 17  #台中旅遊 #台中美食 #欣欣乾洗廠 #宮原眼科 #櫟社 #屋馬燒肉 #日本和牛 #A5和牛...        39            8
# 18  讓小光帶著大家到處遊玩，享用美食\nP.S.很多觀眾，告知沒有字幕加上聲音很小聲\n所以我已...        17           17
# 19  ※片尾有小彩蛋喔！看完別急著關掉啦！\n\n        這一集的旅行優先，我們帶各位小旅...        38           14
# 20  台中旅遊｜梨山谷關山谷燈光節｜什麼原來機車到不了?_旅行功課還是要做足...｜山谷間的旅行｜...        12            8
# 21  台中下雨戶外景點全泡湯怎麼辦？\n入住林酒店樂林大套房奢華再升級~\n幻覺博物館顛覆你的想像...        19           33
#
#    viewCount                                         transcript
# 0      83076  打給饒炸 我是dd 我現在要去台中 今天是獨旅系列 我跟你說我最近真的 思考了很久 下一趟獨...
# 1      33957  台北俗要來到這個台中的知名景點 宮原眼科 來宮原眼科不是來看眼睛哦 哈哈哈 其實它是賣冰淇淋...
# 2      25212  大家好~我是Anson 歡迎來到Anson TV 明天呢,Anson要去參加台中的 一個的朋...
# 3      23072  她身上的影子 天 天 漂亮 你說她漂亮還是說 我是說影子 老師 你會 鬥雞眼嗎 我不會鬥雞眼...
# 4      16697  你知道台中國光客運已經搬家了嗎？ 現在所在位置是在台中舊火車站站前門口 要跟大家介紹的是國光...
# 5      11761  台中網紅景點，小七也能拍網美照 台中特色7-ELEVEN，夢幻少女系風格的科雅門市\n以糖果...
# 6       5987  哈囉!大家好,我是星哥. 今天帶大家來遊玩 台中一區跟台中二區的景點 好!那我首先講解一下 ...
# 7       5352  哈嚕！大家好，我是棉花糖 今天要帶大家從台中火車搭公車到台中國際機場 哈嚕！那我們現在就要去...
# 8       4974  今天來到這一間 我臉剛做完醫美 好醜 今天來到這一間 最近臺中就是非常爆紅的一間賣麵包的店 ...
# 9       4737  今天跟大家介紹從台中車站搭車去清境農場 我們現在在台中車站 這裡是台中車站復興路的出口 台中...
# 10      4266  就是你一下飛機就會到這個地方來\nWhen you get off the plane, y...
# 11      3623  嘿～你好我是蔡少 今天我們來到了台中草悟道文旅 這邊住一晚 今天我是跟著我兒子一起來這邊住宿...
# 12      2817  哈嚕！大家好我們現在台中國際機場的入境大廳 然後我們要帶大家坐公車到台中火車站~往前走 台中...
# 13      2035  今天天氣非常好，所以當然要來到郊外走走 今天帶大家來到新社的『綠大地景觀咖啡館』 那這個景觀...
# 14      1587  第一次插旗台中 真的 而且我們來到谷關 妳知道為什麼台中的農業生態 這麼地好呢 我知道 因為...
# 15      1397  時辰到大家好我是拾承 那我們今天要去兩個地方第一個是 沙鹿的萬里長城步道第二個 麗水漁港那他...
# 16      1025  早安現在9:50 我們今天來臺中參加一個 Free walking tour  哎 其實在歐...
# 17       963  做得好像那種 山水(水墨)畫 保羅帶你開房間 你會把這個影片 傳到...什麼？ 有注意安全餒...
# 18       645  大家好我是小光 今天呢!!要跟大家一起分享一下 我去[日光溫泉]的~泡湯活動 他們推出一個活...
# 19       575  這個是以前 台灣最有錢 最大的豪宅 那被發現不就要 砍頭 砍砍砍砍砍 安室奈美惠 就在這上面...
# 20       341  這次的旅程是在12月份的時間 計劃是從豐原到谷關在到梨山 沒想到這樣的路程看到美好的資訊當下...
# 21       319

# %%
transcript_data.rename(columns = {'transcript':'comment'}, inplace = True)
tfidf_dataframe = text_cleaning.doc_clean(transcript_data)
tfidf_dataframe
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DALab\AppData\Local\Temp\jieba.cache
# Loading model cost 0.669 seconds.
# Prefix dict has been built successfully.
# D:\課程\text mining\project\project_2\formal\text_cleaning.py:112: RuntimeWarning: divide by zero encountered in double_scalars
#   factor=1.0/np.sqrt(sum([np.square(i) for i in dic.values()]))
#             之後來        系列        公園        時空        樓梯        混合       沐浴乳  \
# doc0   0.027021  0.017417  0.054041  0.062884  0.034834  0.027021  0.020961
# doc1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc3        NaN  0.017893       NaN       NaN       NaN       NaN       NaN
# doc4        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc6        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc9        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc10       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc11       NaN       NaN       NaN       NaN       NaN       NaN  0.105954
# doc12       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc13       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc14       NaN  0.007767       NaN       NaN       NaN       NaN       NaN
# doc15       NaN       NaN       NaN       NaN  0.037578       NaN       NaN
# doc16       NaN       NaN       NaN  0.020845       NaN       NaN       NaN
# doc17       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc19       NaN       NaN       NaN       NaN  0.099398       NaN       NaN
# doc20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#              超好       巧克力        心得  ...        山貼        燈光       聖誕樹  \
# doc0   0.027021  0.074511  0.054041  ...       NaN       NaN       NaN
# doc1        NaN  0.096254       NaN  ...       NaN       NaN       NaN
# doc2        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc3        NaN  0.045929       NaN  ...       NaN       NaN       NaN
# doc4        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc5        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc6        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc7        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc8        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc9        NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc10       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc11       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc12       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc13       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc14       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc16       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc17       NaN  0.021879       NaN  ...       NaN       NaN       NaN
# doc18       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc19       NaN       NaN       NaN  ...       NaN       NaN       NaN
# doc20       NaN       NaN       NaN  ...  0.062158  0.062158  0.124317
# doc21       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#              黑熊         修       沒有電        半個        攀登        永遠       往谷關
# doc0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc4        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc6        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc9        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc10       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc11       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc12       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc13       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc14       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc15       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc17       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc19       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# doc20  0.062158  0.062158  0.062158  0.062158  0.062158  0.062158  0.062158
# doc21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [22 rows x 4499 columns]

# %%
selected_words_data = text_cleaning.select_pos_neg_word(tfidf_dataframe)
file_name = './'+keyword+"/top10_words"
visualization.bar_chart(transcript_data,file_name)
# Out:
# C:\Users\DALab\anaconda3\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
file_name = './'+keyword+"/all_wordcloud"+"(num_"+str(len(transcript_data))+")"
visualization.word_cloud(transcript_data,file_name)

# %% [markdown]
# 分析單一doc

# %%
word_list = transcript_data['words'][0]

# %%
file_name = './'+keyword+"/"+transcript_data['title'][0]+'_wordcloud'

# %%
visualization.word_cloud_one_doc(word_list,file_name)

# %%
file_name = './'+keyword+"/"+transcript_data['title'][0]+'_barchart'
visualization.bar_chart_one_doc(word_list,file_name)

# %%
# 單一分析所有doc
import string
import os
for i in range(len(transcript_data)):
    title = transcript_data['title'][i]
     # 把奇怪字串移除
    exclude = set(string.punctuation)
    file = ''.join(ch for ch in title if ch not in exclude)
    #字串最後可能會是space
    if(file[-1] == ' '):
        file = file[:-1]
    os.makedirs('./'+ keyword+'/'+file)
    word_list = transcript_data['words'][i]
    loc = './'+ keyword+'/'+file
    file_name = loc+'/wordcloud'
    visualization.word_cloud_one_doc(word_list,file_name)
    file_name = loc+'/barchart'
    visualization.bar_chart_one_doc(word_list,file_name)
